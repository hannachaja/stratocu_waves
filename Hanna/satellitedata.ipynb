# %%
import xarray as xr

# %%
# !ls /Users/hannachaja/Box/GWaves_2023_10_11-14_SEPAC/IR/Data/IR_2023_09_28_01_15.nc
# Out:
# /Users/hannachaja/Box/GWaves_2023_10_11-14_SEPAC/IR/Data/IR_2023_09_28_01_15.nc

# %%
ds=xr.open_dataset("/Users/hannachaja/Box/GWaves_2023_10_11-14_SEPAC/IR/Data/IR_2023_09_28_01_15.nc")

# %%
ds
# Out:
# <xarray.Dataset> Size: 7MB
# Dimensions:    (latitude: 1125, longitude: 1500)
# Coordinates:
#   * latitude   (latitude) float32 4kB 9.94 9.9 9.86 ... -34.94 -34.98 -35.02
#   * longitude  (longitude) float32 6kB -129.9 -129.9 -129.9 ... -70.02 -69.98
# Data variables:
#     CMI        (latitude, longitude) float32 7MB ...
# Attributes: (12/28)
#     naming_authority:          gov.nesdis.noaa
#     Conventions:               CF-1.7
#     Metadata_Conventions:      Unidata Dataset Discovery v1.0
#     standard_name_vocabulary:  CF Standard Name Table (v35, 20 July 2016)
#     institution:               DOC/NOAA/NESDIS > U.S. Department of Commerce,...
#     project:                   GOES
#     ...                        ...
#     time_coverage_start:       2023-09-28T01:20:20.7Z
#     time_coverage_end:         2023-09-28T01:29:52.7Z
#     timeline_id:               ABI Mode 6
#     production_data_source:    Realtime
# ...

# %%
ds.CMI.plot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 ds.CMI.plot()
#
# File ~/Applications/anaconda3/envs/stratocu_waves/lib/python3.13/site-packages/xarray/plot/accessor.py:48, in DataArrayPlotAccessor.__call__(self, **kwargs)
#      46 @functools.wraps(dataarray_plot.plot, assigned=("__doc__", "__annotations__"))
#      47 def __call__(self, **kwargs) -> Any:
# ---> 48     return dataarray_plot.plot(self._da, **kwargs)
#
# File ~/Applications/anaconda3/envs/stratocu_waves/lib/python3.13/site-packages/xarray/plot/dataarray_plot.py:310, in plot(darray, row, col, col_wrap, ax, hue, subplot_kws, **kwargs)
#     306     plotfunc = hist
#     308 kwargs["ax"] = ax
# --> 310 return plotfunc(darray, **kwargs)
#
# ...
